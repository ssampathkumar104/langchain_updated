# %% [markdown]
# ### Model Integration

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Open AI Model Integration

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gpt-5-2025-08-07",
    temperature=0.7,
    # max_tokens=100,
    timeout=10,
    api_key=os.getenv("OPENAI_API_KEY"),
)

# %%
model.invoke("How many countries are officially recognised by the UN as on date?")
# Out:
# AIMessage(content='- UN member states: 193\n- Plus 2 non-member observer states (Holy See and State of Palestine), making 195 often cited as the total number of “countries” associated with the UN.\n\nNote: The UN doesn’t formally “recognize” countries; admission to membership is the practical benchmark.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 456, 'prompt_tokens': 19, 'total_tokens': 475, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D6WLqhsjSmPDzz65Wen9TF63decEh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c36d8-8ab0-7561-a238-a2b06d62af63-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 456, 'total_tokens': 475, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})

# %% [markdown]
# Open AI Chat

# %%
from langchain_openai import ChatOpenAI

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

model = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0.7,
    # max_tokens=100,
    timeout=10,
    api_key=os.getenv("OPENAI_API_KEY"),
)

# %%
model.invoke("Hello, how are you?")
# Out:
# AIMessage(content="Hello! I'm just a computer program, so I don't have feelings, but I'm here to help you with anything you need. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 13, 'total_tokens': 48, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D6WM0SgLOEN54qUKvXdIk2NTDoPZJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c36d8-de86-7392-9291-eaf8fabbe581-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 35, 'total_tokens': 48, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### Google Gemini Model Integration

# %%
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model(
    model="google_genai:gemini-2.5-flash-lite",
    temperature=0.7,
    # max_tokens=100,
    timeout=10,
    api_key=os.getenv("GOOGLE_API_KEY"),
)

# %%
model.invoke("How many models are available in Google gemini for AI developers to use?")
# Out:
# AIMessage(content='As of my last update, Google Gemini offers **multiple models** for AI developers to use, not just one. The specific number and names of these models can evolve, but the core offering is typically presented as a tiered system to cater to different needs and capabilities.\n\nHere\'s a breakdown of the general approach and what you can expect:\n\n*   **Gemini Ultra:** This is the most capable and powerful model, designed for highly complex tasks, demanding reasoning, and advanced creative generation. It\'s often the flagship model for cutting-edge AI applications.\n\n*   **Gemini Pro:** This model offers a strong balance of capability and efficiency. It\'s suitable for a wide range of general-purpose tasks, from content creation and summarization to coding assistance and question answering. It\'s often the go-to for many developers.\n\n*   **Gemini Nano:** This model is designed for on-device deployment and efficient execution. It\'s optimized for tasks that need to run locally on smartphones or other edge devices, prioritizing speed and resourcefulness.\n\n**Important Considerations:**\n\n*   **API Access:** Developers typically access these models through Google\'s APIs, such as the Vertex AI platform or the Gemini API. The availability of specific models through these APIs might vary slightly.\n*   **Evolving Landscape:** Google is continuously developing and refining its Gemini models. New versions, specialized models, or further tiers might be introduced over time.\n*   **Specific Use Cases:** The "best" model depends heavily on your specific use case. For heavy-duty reasoning, Ultra might be best. For general productivity, Pro is likely ideal. For mobile applications, Nano is the clear choice.\n\n**To get the most up-to-date and precise information, I highly recommend checking the official Google AI or Google Cloud documentation:**\n\n*   **Google AI Studio:** This is a great place to explore Gemini models and their capabilities.\n*   **Vertex AI Documentation:** Google\'s enterprise-grade AI platform provides detailed information on accessing and using Gemini models.\n*   **Gemini API Documentation:** For direct API access, this is the primary source.\n\nBy referring to these official sources, you\'ll find the most current and accurate answer to how many models are available and their specific names and features.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c36d8-e52d-7282-b1f6-ccf47ab74e36-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 473, 'total_tokens': 489, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# Chat Google integration

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    temperature=0.7,
    # max_tokens=100,
    timeout=10,
    api_key=os.getenv("GOOGLE_API_KEY"),
)

# %%
model.invoke("Hello, how are you?")
# Out:
# AIMessage(content='Hello! I am a large language model, trained by Google. I don\'t have feelings or emotions in the same way humans do, so I don\'t experience "how are you?" in the same way.\n\nHowever, I am functioning well and ready to assist you. How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c36d8-f400-7b62-8b43-303b9d9bdde4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 64, 'total_tokens': 71, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# ### Groq Model Integration

# %%
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model(
    model="groq:llama-3.1-8b-instant",
    temperature=0.7,
    # max_tokens=100,
    timeout=10,
    api_key=os.getenv("GROQ_API_KEY"),
)

# %%
response = model.invoke("What is the capital of France?")
response.content
# Out:
# 'The capital of France is Paris.'

# %% [markdown]
# Groq chat

# %%
from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7,
    # max_tokens=100,
    timeout=10,
    api_key=os.getenv("GROQ_API_KEY"),
)

# %%
model.invoke("Hello, how are you?")
# Out:
# AIMessage(content="Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 41, 'total_tokens': 89, 'completion_time': 0.110566143, 'completion_tokens_details': None, 'prompt_time': 0.00197954, 'prompt_tokens_details': None, 'queue_time': 0.048473303, 'total_time': 0.112545683}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c36d9-1d1d-7d31-b2bc-5724a87f83eb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 48, 'total_tokens': 89})

# %% [markdown]
# ### Streaming And Batch
#
# ### Streaming
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses.
# Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model.invoke("Write a 500 words pragraph about what is Artificial Intelligence?")
# Out:
# AIMessage(content='Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that would typically require human intelligence, such as learning, problem-solving, decision-making, and perception. These systems use algorithms and data to enable machines to think and act like humans, and they have the potential to revolutionize numerous industries and aspects of our lives. The term "Artificial Intelligence" was first coined in 1956 by John McCarthy, a computer scientist and cognitive scientist, who defined it as "the science and engineering of making intelligent machines." Since then, AI has evolved significantly, with advancements in machine learning, natural language processing, and computer vision, among other areas. AI systems can be categorized into two main types: narrow or weak AI, which is designed to perform a specific task, such as facial recognition or language translation, and general or strong AI, which is a hypothetical AI system that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks, similar to human intelligence. Currently, most AI systems are narrow AI, and they are being used in various applications, including virtual assistants, such as Siri and Alexa, self-driving cars, medical diagnosis, and personalized recommendation systems. The development of AI has been made possible by the availability of large amounts of data, advancements in computing power, and improvements in algorithms and machine learning techniques. Machine learning, a key aspect of AI, involves training algorithms on large datasets, enabling them to learn patterns and make predictions or decisions without being explicitly programmed. Deep learning, a subset of machine learning, uses neural networks to analyze data, and it has been instrumental in achieving state-of-the-art results in areas such as image recognition, speech recognition, and natural language processing. AI has numerous benefits, including increased efficiency, improved accuracy, and enhanced decision-making capabilities. For instance, AI-powered systems can analyze vast amounts of data quickly and accurately, making them ideal for applications such as medical diagnosis, financial analysis, and quality control. Additionally, AI can automate repetitive and mundane tasks, freeing up human resources for more creative and strategic endeavors. However, AI also raises important ethical and societal concerns, such as job displacement, bias, and privacy. As AI systems become more pervasive, there is a growing need to ensure that they are transparent, accountable, and aligned with human values. Furthermore, there is a need to develop regulations and guidelines that govern the development and deployment of AI systems, particularly in areas such as autonomous vehicles, healthcare, and education. In conclusion, Artificial Intelligence is a rapidly evolving field that has the potential to transform numerous aspects of our lives. From virtual assistants to self-driving cars, AI systems are becoming increasingly ubiquitous, and their applications are expanding into areas such as healthcare, finance, and education. As AI continues to advance, it is essential to address the ethical and societal implications of these technologies, ensuring that they are developed and used in ways that benefit humanity and promote a better future for all. With its vast potential and numerous applications, AI is poised to revolutionize the way we live, work, and interact with each other, and it is crucial that we prioritize responsible AI development and deployment to maximize its benefits while minimizing its risks.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 643, 'prompt_tokens': 48, 'total_tokens': 691, 'completion_time': 1.550456008, 'completion_tokens_details': None, 'prompt_time': 0.004925831, 'prompt_tokens_details': None, 'queue_time': 0.04831775, 'total_time': 1.555381839}, 'model_name': 'llam ...

# %%
model.stream("Write a 500 words pragraph about what is Artificial Intelligence")
# Out:
# <generator object BaseChatModel.stream at 0x000002CD9DDC32E0>

# %%
for chunk in model.stream("Write a 500 words pragraph about what is Artificial Intelligence"):
    print(chunk.content, end="||", flush=True)
# Out:
# ||Art||ificial|| Intelligence|| (||AI||)|| refers|| to|| the|| development|| of|| computer|| systems|| that|| can|| perform|| tasks|| that|| would|| typically|| require|| human|| intelligence||,|| such|| as|| learning||,|| problem||-solving||,|| decision||-making||,|| and|| perception||.|| These|| systems|| use|| algorithms|| and|| data|| to|| enable|| machines|| to|| think|| and|| act|| like|| humans||,|| and|| have|| the|| potential|| to|| revolution||ize|| numerous|| industries|| and|| aspects|| of|| our|| lives||.|| AI|| involves|| a|| broad|| range|| of|| disciplines||,|| including|| computer|| science||,|| mathematics||,|| engineering||,|| and|| cognitive|| psychology||,|| and|| has|| been|| a|| subject|| of|| research|| and|| development|| for|| several|| decades||.|| The|| term|| "||Art||ificial|| Intelligence||"|| was|| first|| coined|| in|| ||195||6|| by|| John|| McCarthy||,|| a|| computer|| scientist|| and|| cognitive|| scientist||,|| who|| defined|| it|| as|| "||the|| science|| and|| engineering|| of|| making|| intelligent|| machines||."|| Since|| then||,|| AI|| has|| evolved|| significantly||,|| with|| the|| development|| of|| various|| techniques|| and|| tools||,|| such|| as|| machine|| learning||,|| deep|| learning||,|| natural|| language|| processing||,|| and|| computer|| vision||.|| Machine|| learning||,|| a|| key|| aspect|| of|| AI||,|| involves|| the|| use|| of|| algorithms|| and|| statistical|| models|| to|| enable|| machines|| to|| learn|| from|| data||,|| without|| being|| explicitly|| programmed||.|| This|| allows|| AI|| systems|| to|| improve|| their|| performance|| over|| time||,|| and|| to|| make|| predictions|| or|| decisions|| based|| on|| new||,|| unseen|| data||.|| AI|| has|| numerous|| applications||,|| including|| virtual|| assistants||,|| such|| as|| Siri|| and|| Alexa||,|| which|| use|| natural|| language|| processing|| to|| understand|| and|| respond|| to|| voice|| commands||;|| image|| recognition|| systems||,|| which|| can|| identify|| objects|| and|| people|| in|| images||;|| and|| self||-driving|| cars||,|| which|| use|| a|| combination|| of|| sensors||,|| GPS||,|| and|| AI|| algorithms|| to|| navigate|| roads|| and|| avoid|| obstacles||.|| Additionally||,|| AI|| is|| being|| used|| in|| healthcare|| to|| analyze|| medical|| images|| and|| diagnose|| diseases||,|| in|| finance|| to|| detect|| fraud|| and|| predict|| stock|| prices||,|| and|| in|| education|| to|| personalize|| learning|| experiences|| for|| students||.|| The|| potential|| benefits|| of|| AI|| are|| vast||,|| and|| include|| increased|| efficiency||,|| productivity||,|| and|| accuracy||,|| as|| well|| as|| the|| ability|| to|| automate|| repetitive|| and|| mundane|| tasks||,|| freeing|| up|| humans|| to|| focus|| on|| more|| creative|| and|| strategic|| work||.|| However||,|| AI|| also|| raises|| important|| questions|| and|| concerns||,|| such|| as|| the|| potential|| for|| job|| displacement||,|| bias|| in|| AI|| decision||-making||,|| and|| the|| need|| for|| transparency|| and|| accountability|| in|| AI|| systems||.|| Furthermore||,|| as|| AI|| becomes|| increasingly|| pervasive||,|| there|| is|| a|| growing|| need|| for|| AI|| literacy|| and|| education||,|| to|| ensure|| that|| people|| understand|| the|| capabilities|| and|| limitations|| of|| AI||,|| and|| can|| effectively|| work|| with|| AI|| systems||.|| Despite|| these|| challenges||,|| AI|| is|| likely|| to|| continue|| to|| play|| a|| major|| role|| in|| shaping|| the|| future|| of|| technology|| and|| society||,|| and|| has|| the|| potential|| to|| drive|| significant|| innovations|| and|| improvements|| in|| numerous|| fields||.|| As|| AI|| continues|| to|| evolve|| and|| improve||,|| we|| can|| expect|| to|| see|| new|| and|| exciting|| applications||,|| such|| as|| the|| development|| of|| intelligent|| robots||,|| autonomous|| drones||,|| and|| smart|| homes||,|| which|| will|| transform|| the|| way|| we|| live||,|| work||,|| and|| interact|| with|| each ...

# %% [markdown]
# #### Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers for a variety of reasons, including:\n\n1. **Mating and Attraction**: Bright, vibrant feathers can be an attractive feature to potential mates. Parrots use their colorful plumage to signal their health, fertility, and genetic quality to other parrots.\n2. **Communication and Social Signaling**: Parrots use their feathers to communicate with other parrots, conveying information about their identity, status, and intentions. Different colors and patterns can signal dominance, submission, or friendship.\n3. **Camouflage and Protection**: While it may seem counterintuitive, some parrots' bright colors can actually serve as camouflage in their natural environments. For example, the bright green feathers of some parrots can help them blend in with the foliage of their rainforest habitats.\n4. **Thermoregulation**: Some parrots' colorful feathers can help regulate their body temperature. For example, the black feathers on a parrot's back can absorb heat, while the white feathers on its belly can reflect it.\n5. **Evolutionary Adaptation**: Parrots' colorful feathers may have evolved as an adaptation to their environment. For example, the bright colors of some parrots may have evolved to mimic the colors of toxic or distasteful animals, warning potential predators to stay away.\n6. **Visual Display**: Parrots use their colorful feathers to create visual displays, such as courtship displays or threat displays. These displays can help establish dominance, attract a mate, or deter a predator.\n7. **Genetic Variation**: Some parrots' colorful feathers may simply be a result of genetic variation, with different populations or species exhibiting unique color patterns and combinations.\n\nIt's worth noting that parrots' colorful feathers are not just for show; they also play a crucial role in the birds' overall health and well-being. For example, the pigments that create the colors in parrots' feathers can also have antioxidant properties, helping to protect the birds from oxidative stress and disease.\n\nOverall, the colorful feathers of parrots are an remarkable example of evolutionary adaptation, serving multiple purposes and playing a vital role in the birds' survival and success." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 437, 'prompt_tokens': 43, 'total_tokens': 480, 'completion_time': 1.5144393059999999, 'completion_tokens_details': None, 'prompt_time': 0.001990651, 'prompt_tokens_details': None, 'queue_time': 0.048436949, 'total_time': 1.5164299570000002}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019c36d9-2b91-73f2-95c0-081f76db4fb2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 43, 'output_tokens': 437, 'total_tokens': 480}
# content="Airplanes fly by using a combination of four main forces: lift, weight, thrust, and drag. Here's a simplified explanation of how these forces work together to keep an airplane in the air:\n\n1. **Lift**: Lift is the upward force that opposes the weight of the airplane and keeps it flying. It's created by the wings, which are designed to produce a difference in air pressure above and below the wing. As the airplane moves forward, the air flows over and under the wing, creating a region of lower pressure above the wing and a region of higher pressure below it. This pressure difference creates an upward force, or lift, that helps to counteract the weight of the airplane.\n2. **Weight**: Weight is the downward force that is equal to the mass of the airplane. It's the combined weight of the airplane itself, the passengers, cargo, and fuel.\n3. **Thrust**: Thrust is the forward force that propels the airplane through the air. It's created by the airplane's engines, which produce a stream of high-speed air that exits the back of the airplane. As this air exits, it produces a forward force that helps to overcome the drag, or resistance, created by the air.\n4. **Drag**: Drag is the backward force that opposes the motion of the airplane. It's created by the air resistance that the airplane encounters as it moves through the air. Drag is affected by the shape of the airplane, its speed, and the density of the air.\n\nWhen an airplane is in flight, the four forces are in balance:\n\n* Lift equals weight (upward force equals downward force)\n* Thrust equals drag (forward force equals backward force)\n\nThe shape of the wing is critical to creating lift. The wing is curved on top and flat on the bottom. As the airplane moves forward, the air flows over and under the wing, creating a difference in air pressure. The air flows faster over the top of the wing, which creates a region of lower pressure above the wing. The air flows slower under the wing, which creates a region of higher pressure below the wing. This pressure difference creates the upward force, or lift, that helps to counteract the weight of the airplane.\n\nAdditionally, the angle of attack of the wing, which is the angle between the wing and the oncoming airflow, also affects the amount of lift generated. As the angle of attack increases, the lift increases, but if it becomes too great, the wing can stall, and the airplane can lose lift.\n\nIn summary, airplanes fly by using the shape of the wing to create lift, the engines to create thrust, and the control surfaces to control the direction of the airplane. The four forces of lift, weight, thrust, and drag work together to keep the airplane in the air and moving in the desired direction." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 576, 'prompt_tokens': 40, 'total_tokens': 616, 'completion_time': 1.50375267, 'completion_tokens_details': None, 'prompt_time': 0.001734261, 'prompt_tokens_details': None, 'queue_time': 0.04816903, 'total_time': 1.505486931}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019c36d9-2b94-75e1-b5cf-ae9f7a56864b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 576, 'total_tokens': 616}
# content='Quantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It\'s a new paradigm for computing that\'s different from classical computing, which is the type of computing we\'re familiar with today.\n\n**Classical Computing vs. Quantum Computing**\n\nClassical computers use bits to store and process information. A bit is a binary digit that can have a value of either 0 or 1. These bits are used to perform calculations and operations using logical gates, which are the building blocks of digital circuits.\n\nQuantum computers, on the other hand, use quantum bits or qubits. Qubits are unique because they can exist in multiple states simultaneously, which is known as a superposition. This means that a qubit can represent not just 0 or 1, but also any linear combination of 0 and 1, like 0.5 or 0.75. This property allows quantum computers to process a vast number of possibilities simultaneously, making them potentially much faster than classical computers for certain types of calculations.\n\n**Key Features of Quantum Computing**\n\n1. **Superposition**: Qubits can exist in multiple states at the same time, allowing for the exploration of an exponentially large solution space.\n2. **Entanglement**: Qubits can become "entangled," meaning that the state of one qubit is dependent on the state of another, even if they\'re separated by large distances.\n3. **Quantum parallelism**: Quantum computers can perform many calculations simultaneously, thanks to the principles of superposition and entanglement.\n4. **Quantum interference**: Quantum computers can exploit the interference patterns that arise from the interactions between qubits to solve problems more efficiently.\n\n**Applications of Quantum Computing**\n\nQuantum computing has the potential to revolutionize many fields, including:\n\n1. **Cryptography**: Quantum computers can break certain classical encryption algorithms, but they can also be used to create new, quantum-resistant encryption methods.\n2. **Optimization**: Quantum computers can be used to solve complex optimization problems, such as finding the shortest path in a network or the most efficient way to schedule tasks.\n3. **Simulation**: Quantum computers can simulate complex systems, such as molecules and chemical reactions, which could lead to breakthroughs in fields like chemistry and materials science.\n4. **Machine learning**: Quantum computers can be used to speed up certain machine learning algorithms, which could lead to advances in areas like image recognition and natural language processing.\n\n**Challenges and Limitations**\n\nWhile quantum computing has the potential to revolutionize many fields, it\'s still a developing technology with many challenges and limitations. Some of the key challenges include:\n\n1. **Error correction**: Quantum computers are prone to errors due to the noisy nature of quantum systems. Developing robust error correction methods is essential for large-scale quantum computing.\n2. **Scalability**: Currently, most quantum computers are small-scale and can only perform a limited number of operations. Scaling up to larger systems is a significant challenge.\n3. **Quantum control**: Maintaining control over the quantum states of qubits is essential for reliable quantum computing.\n\nOverall, quantum computing is a rapidly advancing field that has the potential to transform many areas of science and engineering. While there are still many challenges to overcome, the potential rewards are significant, and researchers are making rapid progress in developing this exciting technology.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 678, 'prompt_tokens': 40, 'total_tokens': 718, 'completion_time': 1.747491008, 'completion_tokens_details': None, 'prompt_time': 0.001735301, 'prompt_tokens_details': None, 'queue_time': 0.0480343, 'total_time': 1.749226309}, 'model_name': 'llama ...

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content="Parrots have colorful feathers for several reasons, including:\n\n1. **Communication and Expression**: Colorful feathers help parrots communicate with each other, expressing emotions, intentions, and social status. Different colors can signal dominance, courtship, or warning calls.\n2. **Mating and Attraction**: Vibrant plumage is often used to attract a mate. Bright colors can indicate a parrot's health, fertility, and genetic quality, making them more attractive to potential partners.\n3. **Camouflage and Defense**: Some parrot species have feathers with colors that help them blend in with their surroundings, making it harder for predators to spot them. Others have bright colors that serve as a warning to potential predators, signaling that they are toxic or distasteful.\n4. **Thermoregulation**: Dark-colored feathers can absorb heat, while light-colored feathers can reflect it. This helps parrots regulate their body temperature in different environments.\n5. **Evolutionary Adaptation**: The colorful feathers of parrots have evolved over time to adapt to their environment and ecological niches. For example, the bright colors of some parrot species may have evolved to match the colors of their food sources, such as fruits and flowers.\n6. **Social Signaling**: Parrots use their colorful feathers to signal their social status, age, and sex. For example, some species have distinctive coloration on their heads, wings, or tails that indicate their dominance or submissiveness.\n7. **Genetic Variation**: The genetic diversity of parrot populations can result in a wide range of colorful feather variations, which can be influenced by factors such as diet, climate, and geography.\n\nOverall, the colorful feathers of parrots play a crucial role in their behavior, ecology, and evolution, and are an important aspect of their unique biology and charm.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 371, 'prompt_tokens': 43, 'total_tokens': 414, 'completion_time': 0.256807198, 'completion_tokens_details': None, 'prompt_time': 0.07003171, 'prompt_tokens_details': None, 'queue_time': None, 'total_time': 0.326838908}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c36d9-32f9-7cc2-aa33-7909e628d254-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 371, 'total_tokens': 414}),
#  AIMessage(content="Airplanes fly by using the principles of aerodynamics to generate lift, thrust, and control. Here's a simplified explanation of how they work:\n\n**The Four Forces of Flight:**\n\n1. **Lift**: The upward force that opposes the weight of the plane and keeps it flying. Lift is created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the plane moves forward, the air flows over and under the wing, creating an area of lower pressure above the wing and an area of higher pressure below. This pressure difference creates an upward force, or lift, that counteracts the weight of the plane.\n2. **Weight**: The downward force that is the combined weight of the plane, passengers, cargo, and fuel.\n3. **Thrust**: The forward force that propels the plane through the air. Thrust is created by the plane's engines, which produce a stream of high-speed air that exits the back of the plane. As the air exits, it produces a forward force that counteracts the drag, or resistance, of the air.\n4. **Drag**: The backward force that opposes the motion of the plane. Drag is created by the friction between the plane and the air, as well as the shape of the plane itself.\n\n**How Airplanes Fly:**\n\n1. **Takeoff**: When an airplane takes off, the engines produce thrust, which propels the plane forward. As the plane gains speed, the wings begin to produce lift, which helps to counteract the weight of the plane.\n2. **Climb**: As the plane gains altitude, the engines continue to produce thrust, and the wings produce lift. The plane climbs at an angle, with the nose pointing slightly upward.\n3. **Cruise**: Once the plane reaches its desired altitude, the engines produce a steady thrust, and the wings produce a steady lift. The plane flies level, with the nose pointing straight ahead.\n4. **Descent**: When the plane begins to descend, the engines produce less thrust, and the wings produce less lift. The plane descends at an angle, with the nose pointing slightly downward.\n\n**Control Surfaces:**\n\nAirplanes have several control surfaces that help to control the direction and attitude of the plane. These include:\n\n* **Ailerons**: Located on the wings, ailerons control roll, or the rotation of the plane around its longitudinal axis.\n* **Elevators**: Located on the tail, elevators control pitch, or the rotation of the plane around its lateral axis.\n* **Rudder**: Located on the tail, the rudder controls yaw, or the rotation of the plane around its vertical axis.\n\n**In Summary:**\n\nAirplanes fly by using the principles of aerodynamics to generate lift, thrust, and control. The shape of the wings produces lift, while the engines produce thrust. The control surfaces help to control the direction and attitude of the plane, allowing it to take off, climb, cruise, and descend safely and efficiently.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 621, 'prompt_tokens': 40, 'total_tokens': 661, 'completion_time': 1.249690421, 'completion_tokens_details': None, 'prompt_time': 0.001008146, 'prompt_tokens_details': None, 'queue_time': 0.049579784, 'total_time': 1.250698567}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c36d9-32fb-76d0-8ee0-315c7009f852-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 621, 'total_tokens': 661}),
#  AIMessage(content='Quantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It\'s a new paradigm for computing that has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve using traditional computers.\n\n**Classical vs. Quantum Computing**\n\nClassical computers use "bits" to process information, which can have a value of either 0 or 1. These bits are used to perform calculations and operations using logical gates, which are the basic building blocks of digital circuits. However, as the number of bits increases, the complexity of the calculations grows exponentially, making it difficult to solve certain problems.\n\nQuantum computers, on the other hand, use "qubits" (quantum bits), which can exist in multiple states simultaneously, known as a superposition. This means that a qubit can represent not just 0 or 1, but also any linear combination of 0 and 1, such as 0.5 or 0.75. Qubits can also become "entangled," meaning that their properties are connected, even when separated by large distances.\n\n**Key Features of Quantum Computing**\n\n1. **Superposition**: Qubits can exist in multiple states simultaneously, allowing for parallel processing of multiple possibilities.\n2. **Entanglement**: Qubits can become connected, enabling the creation of a collective quantum state.\n3. **Quantum gates**: Quantum computers use quantum gates, which are the quantum equivalent of logical gates, to manipulate qubits and perform operations.\n4. **Quantum parallelism**: Quantum computers can perform many calculations simultaneously, thanks to the principles of superposition and entanglement.\n\n**Potential Applications of Quantum Computing**\n\n1. **Cryptography**: Quantum computers can potentially break certain classical encryption algorithms, but they can also be used to create new, quantum-resistant encryption methods.\n2. **Optimization problems**: Quantum computers can solve complex optimization problems, such as the traveling salesman problem, more efficiently than classical computers.\n3. **Simulations**: Quantum computers can simulate complex quantum systems, such as molecules and chemical reactions, which could lead to breakthroughs in fields like chemistry and materials science.\n4. **Machine learning**: Quantum computers can be used to speed up certain machine learning algorithms, such as k-means and support vector machines.\n\n**Current State of Quantum Computing**\n\nWhile quantum computing is still in its early stages, significant progress has been made in recent years. Several companies, including Google, IBM, and Microsoft, are actively developing quantum computing hardware and software. However, many technical challenges need to be overcome before quantum computing becomes a practical reality.\n\n**Challenges and Limitations**\n\n1. **Noise and error correction**: Quantum computers are prone to errors due to the fragile nature of qubits, which can lose their quantum properties due to interactions with the environment.\n2. **Scalability**: Currently, quantum computers are small-scale and need to be scaled up to perform complex calculations.\n3. **Quantum control**: Maintaining control over qubits and quantum gates is essential for reliable operation.\n\nIn summary, quantum computing has the potential to revolutionize the way we approach complex problems, but it\'s still an emerging field with many challenges to overcome. As research and development continue, we can expect to see significant advancements in the coming years.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 676, 'prompt_tokens': 40, 'total_tokens': 716, 'completion_time': 0.864100704, 'completion_tokens_details': None, 'prompt_time': 0.093307274, 'prompt_tokens_details': None, 'queue_time': None, 'total_time': 0.957407978}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint' ...
